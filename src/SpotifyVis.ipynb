# %%
import pandas as pd
from Modules.read_data import read_data
from Modules.handle_time import transform_time_and_duration
from Modules.handle_genres import *
from Questions.q_one_taste_evolution import plot_taste_evolution

# %% [markdown]
# ## **Variables**

# %%
data_path_25 = '/Users/juanpazmino/Documents/Desarrollo/Personal_projects/SpotifyDataVis/data/2025/'
data_path_26 = '/Users/juanpazmino/Documents/Desarrollo/Personal_projects/SpotifyDataVis/data/2026/'

saved_tracks_25 = 'saved_tracks_20251018.csv'
track_details_25 = 'track_details_20251018.csv'

# Playlist

# %% [markdown]
# ## **Lectura de los datos**

# %%
df_saved_tracks_25 = read_data(data_path_25, saved_tracks_25)
df_track_details_25 = read_data(data_path_25, track_details_25)

# %%
df_saved_tracks_25.head()
# Out:
#                  track_id                      track_name  \
# 0  2aAjWdZ7TsQYvyRUzAFXmB                   Young Forever
# 1  3G8AJXzCrwPCnHiQI1ENnm                         Plumbum
# 2  4VmcBQm0YzgK0MU5geXmNA                        Godspeed
# 3  4wpX2rcuD8R6f9P78yzccy                       Timelapse
# 4  7pt0UDWnpiVJ1uEMP5iM0P  No Broke Boys - Lee Foss Remix
#
#                       artist_name               artist_id  \
# 0                     Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 1                            1luu  6H7YXIE4ZT1Nxa2krwL6N4
# 2                             ADB  12YduHZJsgoAQlzLEDdT8T
# 3                            TRYM  5Nd385K2g3s0828W8Ab70z
# 4  Disco Lines, Tinashe, Lee Foss  5Kmr0b3ip8g9P2i0dLTC3Z
#
#                        album_name                album_id release_date  \
# 0                   Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17
# 1                     Europium EP  0l22YC5T2pj3MvIxPMt9iT   2025-02-21
# 2                        Godspeed  0B3oIXhodX3Xb64ehNSAOn   2025-01-31
# 3                       Timelapse  4ZbUxkHSXVHU499uVMjawk   2018-09-04
# 4  No Broke Boys (Lee Foss Remix)  4pWH8vGb2ZmwdAdZqMqcJO   2025-10-03
#
#    duration_ms  popularity              added_at  explicit
# 0       227091           0  2025-10-17T20:33:46Z     False
# 1       361414           9  2025-10-14T23:36:59Z     False
# 2       175889          10  2025-10-14T23:35:22Z     False
# 3       370285          27  2025-10-11T03:51:31Z     False
# 4       209333          56  2025-10-03T21:24:49Z      True

# %%
df_track_details_25.head()
# Out:
#                  track_id                                     track_name  \
# 0  3LBWAYCXn4GCkg0jOgWD7D                         Breathe In (Short Mix)
# 1  3G8AJXzCrwPCnHiQI1ENnm                                        Plumbum
# 2  4VmcBQm0YzgK0MU5geXmNA                                       Godspeed
# 3  1rbJVNRXE8jASvaAzWw9s8  Diving with Whales - Daniel Portman Radio Mix
# 4  3HER2Njuttsq8Qs8sn2G1Y            On The Beat - Full Length Album Mix
#
#    duration_ms  popularity  explicit  \
# 0       247559          46     False
# 1       361414           9     False
# 2       175889          10     False
# 3       268292          27     False
# 4       357720          44     False
#
#                                        artist_genres
# 0  melodic techno, melodic house, techno, progres...
# 1                   hard techno, techno, acid techno
# 2                      hard house, eurodance, trance
# 3  deep house, melodic house, progressive house, ...
# 4                            post-disco, disco, funk

# %%
track_details_subset = df_track_details_25[['track_id', 'artist_genres']]
merged_list_details = pd.merge(df_saved_tracks_25, track_details_subset, on='track_id', how='left')

# %%
merged_list_details.head()
# Out:
#                  track_id                      track_name  \
# 0  2aAjWdZ7TsQYvyRUzAFXmB                   Young Forever
# 1  3G8AJXzCrwPCnHiQI1ENnm                         Plumbum
# 2  4VmcBQm0YzgK0MU5geXmNA                        Godspeed
# 3  4wpX2rcuD8R6f9P78yzccy                       Timelapse
# 4  7pt0UDWnpiVJ1uEMP5iM0P  No Broke Boys - Lee Foss Remix
#
#                       artist_name               artist_id  \
# 0                     Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 1                            1luu  6H7YXIE4ZT1Nxa2krwL6N4
# 2                             ADB  12YduHZJsgoAQlzLEDdT8T
# 3                            TRYM  5Nd385K2g3s0828W8Ab70z
# 4  Disco Lines, Tinashe, Lee Foss  5Kmr0b3ip8g9P2i0dLTC3Z
#
#                        album_name                album_id release_date  \
# 0                   Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17
# 1                     Europium EP  0l22YC5T2pj3MvIxPMt9iT   2025-02-21
# 2                        Godspeed  0B3oIXhodX3Xb64ehNSAOn   2025-01-31
# 3                       Timelapse  4ZbUxkHSXVHU499uVMjawk   2018-09-04
# 4  No Broke Boys (Lee Foss Remix)  4pWH8vGb2ZmwdAdZqMqcJO   2025-10-03
#
#    duration_ms  popularity              added_at  explicit  \
# 0       227091           0  2025-10-17T20:33:46Z     False
# 1       361414           9  2025-10-14T23:36:59Z     False
# 2       175889          10  2025-10-14T23:35:22Z     False
# 3       370285          27  2025-10-11T03:51:31Z     False
# 4       209333          56  2025-10-03T21:24:49Z      True
#
#                                        artist_genres
# 0            techno, acid techno, hard techno, tekno
# 1                   hard techno, techno, acid techno
# 2                      hard house, eurodance, trance
# 3            hard techno, techno, acid techno, tekno
# 4  stutter house, alternative r&b, tech house, house

# %%
df_clean_track_list = transform_time_and_duration(merged_list_details)
df_clean_track_list.head()
# Out:
#                  track_id                      track_name  \
# 0  2aAjWdZ7TsQYvyRUzAFXmB                   Young Forever
# 1  3G8AJXzCrwPCnHiQI1ENnm                         Plumbum
# 2  4VmcBQm0YzgK0MU5geXmNA                        Godspeed
# 3  4wpX2rcuD8R6f9P78yzccy                       Timelapse
# 4  7pt0UDWnpiVJ1uEMP5iM0P  No Broke Boys - Lee Foss Remix
#
#                       artist_name               artist_id  \
# 0                     Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 1                            1luu  6H7YXIE4ZT1Nxa2krwL6N4
# 2                             ADB  12YduHZJsgoAQlzLEDdT8T
# 3                            TRYM  5Nd385K2g3s0828W8Ab70z
# 4  Disco Lines, Tinashe, Lee Foss  5Kmr0b3ip8g9P2i0dLTC3Z
#
#                        album_name                album_id release_date  \
# 0                   Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17
# 1                     Europium EP  0l22YC5T2pj3MvIxPMt9iT   2025-02-21
# 2                        Godspeed  0B3oIXhodX3Xb64ehNSAOn   2025-01-31
# 3                       Timelapse  4ZbUxkHSXVHU499uVMjawk   2018-09-04
# 4  No Broke Boys (Lee Foss Remix)  4pWH8vGb2ZmwdAdZqMqcJO   2025-10-03
#
#    popularity                  added_at  explicit  \
# 0           0 2025-10-17 20:33:46+00:00     False
# 1           9 2025-10-14 23:36:59+00:00     False
# 2          10 2025-10-14 23:35:22+00:00     False
# 3          27 2025-10-11 03:51:31+00:00     False
# 4          56 2025-10-03 21:24:49+00:00      True
#
#                                        artist_genres  added_year  added_month  \
# 0            techno, acid techno, hard techno, tekno        2025           10
# 1                   hard techno, techno, acid techno        2025           10
# 2                      hard house, eurodance, trance        2025           10
# 3            hard techno, techno, acid techno, tekno        2025           10
# 4  stutter house, alternative r&b, tech house, house        2025           10
#
#    duration_mins
# 0       3.784850
# 1       6.023567
# 2       2.931483
# 3       6.171417
# 4       3.488883

# %%
df_exploded_track_list = explode_genres(df_clean_track_list)
df_exploded_track_list.head()
# Out:
#                  track_id     track_name  artist_name               artist_id  \
# 0  2aAjWdZ7TsQYvyRUzAFXmB  Young Forever  Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 0  2aAjWdZ7TsQYvyRUzAFXmB  Young Forever  Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 0  2aAjWdZ7TsQYvyRUzAFXmB  Young Forever  Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 0  2aAjWdZ7TsQYvyRUzAFXmB  Young Forever  Amelie Lens  5Ho1vKl1Uz8bJlk4vbmvmf
# 1  3G8AJXzCrwPCnHiQI1ENnm        Plumbum         1luu  6H7YXIE4ZT1Nxa2krwL6N4
#
#       album_name                album_id release_date  popularity  \
# 0  Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17           0
# 0  Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17           0
# 0  Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17           0
# 0  Young Forever  4BOWZWwm6WVWmco0HKt80s   2025-10-17           0
# 1    Europium EP  0l22YC5T2pj3MvIxPMt9iT   2025-02-21           9
#
#                    added_at  explicit  \
# 0 2025-10-17 20:33:46+00:00     False
# 0 2025-10-17 20:33:46+00:00     False
# 0 2025-10-17 20:33:46+00:00     False
# 0 2025-10-17 20:33:46+00:00     False
# 1 2025-10-14 23:36:59+00:00     False
#
#                              artist_genres  added_year  added_month  \
# 0  techno, acid techno, hard techno, tekno        2025           10
# 0  techno, acid techno, hard techno, tekno        2025           10
# 0  techno, acid techno, hard techno, tekno        2025           10
# 0  techno, acid techno, hard techno, tekno        2025           10
# 1         hard techno, techno, acid techno        2025           10
#
#    duration_mins   genre_list
# 0       3.784850       techno
# 0       3.784850  acid techno
# 0       3.784850  hard techno
# 0       3.784850        tekno
# 1       6.023567  hard techno

# %% [markdown]
# ***
# ## **Procesamiento de datos**

# %%
all_genres = get_all_genres(df_exploded_track_list)
all_genres
# Out:
# ['techno',
#  'melodic techno',
#  'melodic house',
#  'acid techno',
#  'progressive house',
#  'hard techno',
#  'minimal techno',
#  'edm',
#  'trance',
#  'tekno',
#  'nu disco',
#  'deep house',
#  'house',
#  'tech house',
#  'french house',
#  'hard house',
#  'big room',
#  'indie dance',
#  'progressive trance',
#  'eurodance',
#  'organic house',
#  'electronica',
#  'lo-fi house',
#  'indie',
#  'new rave',
#  'stutter house',
#  'electroclash',
#  'disco house',
#  'future house',
#  'electro',
#  'afro house',
#  'alternative dance',
#  'electro house',
#  'tropical house',
#  'hypertechno',
#  'funky house',
#  'hardcore techno',
#  'french indie pop',
#  'downtempo',
#  'uk garage',
#  'trip hop',
#  'neue deutsche welle',
#  'indie rock',
#  'alternative rock',
#  'punk',
#  'idm',
#  'phonk',
#  'skate punk',
#  'italo disco',
#  'future bass',
#  'synthwave',
#  'rock',
#  'jazz house',
#  'pop punk',
#  'dubstep',
#  'garage rock',
#  'classic rock',
#  'breakbeat',
#  'witch house',
#  'dub techno',
#  'electronic',
#  'emo',
#  'chillwave',
#  'drum and bass',
#  'slap house',
#  'tribal house',
#  'indie soul',
#  'german indie',
#  'bass house',
#  'synthpop',
#  'art pop',
#  'britpop',
#  'italo dance',
#  'acid house',
#  'gabber',
#  'afro tech',
#  'chillstep',
#  'g-house',
#  'melodic bass',
#  'latin rock',
#  'darkwave',
#  'liquid funk',
#  'industrial',
#  'melbourne bounce',
#  'big beat',
#  'german indie pop',
#  'german pop',
#  'bounce',
#  'hyperpop',
#  'anime',
#  'rock en español',
#  'j-rock',
#  'dream pop',
#  'latin house',
#  'psychedelic rock',
#  'ebm',
#  'hardstyle',
#  'pop',
#  'argentine rock',
#  'nu metal',
#  'disco',
#  'funk',
#  'alternative r&b',
#  'happy hardcore',
#  'brazilian bass',
#  'ska punk',
#  'acid jazz',
#  'french pop',
#  'lo-fi beats',
#  'hardcore punk',
#  'europop',
#  'drift phonk',
#  'lo-fi',
#  'moombahton',
#  'post-hardcore',
#  'neo soul',
#  'rap rock',
#  'alternative metal',
#  'post-punk',
#  'cold wave',
#  'hip hop',
#  'motown',
#  'baroque pop',
#  'funk rock',
#  'glitch',
#  'rally house',
#  'east coast hip hop',
#  'frenchcore',
#  'screamo',
#  'indie electronic',
#  'soft rock',
#  'lo-fi hip hop',
#  'hard rock',
#  'uk r&b',
#  'new wave',
#  'j-pop',
#  'neo-psychedelic',
#  'melodic hardcore',
#  'rap metal',
#  'experimental hip hop',
#  'r&b',
#  'reggae',
#  'rap',
#  'gothic rock',
#  'grime',
#  'nu jazz',
#  'uk funky',
#  'swedish pop',
#  'k-pop',
#  'psytrance',
#  'soundtrack',
#  'soul',
#  'folk pop',
#  'classical',
#  'latin alternative',
#  'german hip hop',
#  'chicago house',
#  'blues rock',
#  'bedroom pop',
#  'dub',
#  'hi-nrg',
#  'bassline',
#  'electro swing',
#  'lounge',
#  'hardcore',
#  'riot grrrl',
#  'ska',
#  'drumstep',
#  'neoclassical',
#  'vaporwave',
#  'classic soul',
#  'glam rock',
#  'post-disco',
#  'dark ambient',
#  'rock and roll',
#  'orchestral',
#  'west coast hip hop',
#  'dancehall',
#  'soft pop',
#  'edm trap',
#  'singer-songwriter',
#  'mexican rock',
#  'trova',
#  'dansk pop',
#  'modern blues',
#  'madchester',
#  'uk drill',
#  'uk grime',
#  'surf rock',
#  'indie punk',
#  'techengue',
#  'minimalism',
#  'latin indie',
#  'yacht rock',
#  'jazz rap',
#  'glam metal',
#  'southern hip hop',
#  'retro soul',
#  'progressive rock',
#  'flamenco',
#  'mexican indie',
#  'folklore argentino',
#  'experimental',
#  'jazz beats',
#  'shoegaze',
#  'deathrock',
#  'speedcore',
#  'queercore',
#  'chanson',
#  'variété française',
#  'jungle',
#  'dance pop',
#  'southern gothic',
#  'drill',
#  'reggaeton',
#  'k-ballad',
#  'bubblegum pop',
#  'metalcore',
#  'ambient',
#  'proto-punk',
#  'chinese indie',
#  'opera',
#  'g-funk',
#  'malay',
#  'malaysian pop',
#  'electropop',
#  'pop soul',
#  'folk rock',
#  'folk',
#  'afrobeats',
#  'ragga',
#  'latin hip hop',
#  'northern soul',
#  'chamber music',
#  'roots reggae',
#  'acid rock',
#  'art rock',
#  'crunk',
#  'visual kei',
#  'neoperreo',
#  'norwegian pop',
#  'french rap',
#  'swing music',
#  'turkish hip hop',
#  'cedm',
#  'cloud rap',
#  'rockabilly',
#  'indie pop',
#  'nova mpb',
#  'boom bap',
#  'noise rock',
#  'indie r&b',
#  'latin',
#  'celtic',
#  'new age',
#  'christian hip hop',
#  'philly soul',
#  'mathcore',
#  'gospel r&b',
#  'indie folk',
#  'math rock',
#  'blues',
#  'jangle pop',
#  'dansktop',
#  'jazz blues',
#  '3 step',
#  'gqom',
#  'reggae rock',
#  'acoustic pop',
#  'industrial rock',
#  'footwork',
#  'old school hip hop',
#  'ballroom vogue',
#  'alternative hip hop',
#  'metal',
#  'french r&b',
#  'pop urbaine',
#  'jazz funk',
#  'bass music',
#  'country',
#  'pop country',
#  'acoustic country',
#  'smooth jazz',
#  'baltimore club',
#  'christmas',
#  'slowcore',
#  'soca',
#  'riddim',
#  'chinese hip hop',
#  'latin folk',
#  'nueva trova',
#  'candombe',
#  'quiet storm',
#  'jam band',
#  'pop québécoise',
#  'stoner rock',
#  'finnish rock',
#  'azonto',
#  'hiplife',
#  'folk punk',
#  'aor',
#  'tango',
#  'schlager',
#  'emo rap',
#  'post-grunge',
#  'grunge',
#  'free jazz',
#  'nederpop',
#  'portuguese hip hop',
#  'symphonic metal',
#  'gothic metal']

# %%
from Questions.q_one_taste_evolution import plot_taste_evolution
chart_q1 = plot_taste_evolution(df_exploded_track_list, top_parents_n=10)
chart_q1.display()
# Out:
# /Users/juanpazmino/Documents/Desarrollo/Personal_projects/SpotifyDataVis/src/Questions/q_one_taste_evolution.py:105: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['added_year_month'] = df['added_at'].dt.to_period('M').dt.to_timestamp()
# alt.Chart(...)
